# %%
# !pip install mysql
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df=pd.read_excel(r"C:\Users\User\Downloads\GUVI\traffic_stops.xlsx")
df
# Out:
#        stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0     2020-01-01  00:00:00       Canada             M              59
# 1     2020-01-01  00:01:00        India             M              35
# 2     2020-01-01  00:02:00          USA             M              26
# 3     2020-01-01  00:03:00       Canada             M              26
# 4     2020-01-01  00:04:00       Canada             M              62
# ...          ...       ...          ...           ...             ...
# 65533 2020-02-15  12:13:00        India             F              54
# 65534 2020-02-15  12:14:00       Canada             F              18
# 65535 2020-02-15  12:15:00          USA             M              27
# 65536 2020-02-15  12:16:00       Canada             F              49
# 65537 2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
# !pip3 list
# Out:
# Package                Version
# ---------------------- -----------
# asttokens              3.0.0
# cffi                   1.17.1
# colorama               0.4.6
# comm                   0.2.2
# cryptography           44.0.2
# debugpy                1.8.13
# decorator              5.2.1
# et_xmlfile             2.0.0
# exceptiongroup         1.2.2
# executing              2.2.0
# ipykernel              6.29.5
# ipython                8.34.0
# jedi                   0.19.2
# jupyter_client         8.6.3
# jupyter_core           5.7.2
# matplotlib-inline      0.1.7
# mysql                  0.0.3
# mysql-connector-python 9.2.0
# mysqlclient            2.2.7
# nest-asyncio           1.6.0
# numpy                  2.2.4
# openpyxl               3.1.5
# packaging              24.2
# pandas                 2.2.3
# parso                  0.8.4
# pip                    23.0.1
# platformdirs           4.3.7
# prompt_toolkit         3.0.50
# psutil                 7.0.0
# ...

# %%
import mysql.connector

# %%
import pymysql
connection=pymysql.connect(
    host = "localhost",
    user="root",
    password="12345678",
    database="securecheck"
)
cursor=connection.cursor()

# %%
#Step2: Data Cleaning 
#Drop colums with all missing values
df.dropna(axis=1,how='all',inplace=True)
#Fillnans with all suitable values
df.fillna({
    'driver_age':df['driver_age'].median(),
    'search_type':'None',
    'stop_duration':'Unknown',
    'violation':'Unknown',
},inplace=True)

# %%
#convert date & time to timestamp
df['timestamp'] = pd.to_datetime(df['stop_date']+' '+df['stop_time'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 #convert date & time to timestamp
# ----> 2 df['timestamp'] = pd.to_datetime(df['stop_date']+' '+df['stop_time'])
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)
#     184     moose     3.0     NaN
#     185     """
# ...

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'country_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'search_type', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'drugs_related_stop', 'vehicle_number'],
#       dtype='object')

# %%
cursor.execute("USE ")
